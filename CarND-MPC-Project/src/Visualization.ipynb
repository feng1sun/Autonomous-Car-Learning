# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('../build/log.json') as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['a', 'delta', 'psi', 'ptsx', 'ptsy', 'px', 'py', 'v'])

# %%
ptsx = np.array(data['ptsx'])
ptsy = np.array(data['ptsy'])
px = np.array(data['px'])
py = np.array(data['py'])
a = np.array(data['a'])
delta = np.array(data['delta'])
psi = np.array(data['psi'])
v = np.array(data['v'])
# x_pts = np.array(data['x_pts'])
# y_pts = np.array(data['y_pts'])


print('ptsx: ', ptsx.shape)
print('ptsx: ', ptsy.shape)
print('px: ', px.shape)
print('py: ', py.shape)
print('a: ', a.shape)
print('v: ', v.shape)
print('psi: ', psi.shape)
print('delta: ', delta.shape)
# print('x_pts: ', x_pts.shape)
# print('y_pts: ', y_pts.shape)
# Out:
# ptsx:  (16, 6)
# ptsx:  (16, 6)
# px:  (16,)
# py:  (16,)
# a:  (16,)
# v:  (16,)
# psi:  (16,)
# delta:  (16,)

# %%
plt.plot(py, px, 'r')
for x, y in zip(ptsx, ptsy):
    plt.plot(y, x)

# %%
# plt.plot(py, px)
for x, y in zip(y_pts, x_pts):
    plt.plot(y, x)

# %%
plt.plot(v)
