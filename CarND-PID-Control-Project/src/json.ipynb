# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('./build/log.json') as f:
    data = json.load(f)

# %%
cte = np.array(data['cte'])
d_error = np.array(data['d_error'])
i_error = np.array(data['i_error'])
p_error = np.array(data['p_error'])
u = np.array(data['control'])
dp0 = np.array(data['dp0'])
dp1 = np.array(data['dp1'])
dp2 = np.array(data['dp2'])
Kp = np.array(data['Kp'])
Ki = np.array(data['Ki'])
Kd = np.array(data['Kd'])

# %%
plt.plot(cte)

# %%
plt.plot(d_error, label='d_error')
plt.plot(i_error, label='i_error')
plt.plot(p_error, label='p_error')
plt.legend()

# %%
# plt.plot(Kp, label='Kp')
plt.plot(Ki, label='Ki')
# plt.plot(Kd, label='Kd')
plt.legend()

# %%
plt.plot(dp0, label='dp')
plt.plot(dp1, label='di')
plt.plot(dp2, label='dd')
plt.legend()

# %%
plt.plot(u)
